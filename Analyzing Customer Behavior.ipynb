# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

df = pd.read_csv('WA_Fn-UseC_-Marketing-Customer-Value-Analysis (2).csv').rename(columns=lambda x: x.strip())
df.columns = df.columns.str.replace(' ', '_')
df.head()
# Out:
#   Customer       State  Customer_Lifetime_Value Response  Coverage Education  \
# 0  BU79786  Washington              2763.519279       No     Basic  Bachelor
# 1  QZ44356     Arizona              6979.535903       No  Extended  Bachelor
# 2  AI49188      Nevada             12887.431650       No   Premium  Bachelor
# 3  WW63253  California              7645.861827       No     Basic  Bachelor
# 4  HB64268  Washington              2813.692575       No     Basic  Bachelor
#
#   Effective_To_Date EmploymentStatus Gender  Income     ...       \
# 0           2/24/11         Employed      F   56274     ...
# 1           1/31/11       Unemployed      F       0     ...
# 2           2/19/11         Employed      F   48767     ...
# 3           1/20/11       Unemployed      M       0     ...
# 4            2/3/11         Employed      M   43836     ...
#
#   Months_Since_Policy_Inception Number_of_Open_Complaints  Number_of_Policies  \
# ...

# %%
df.shape
# Out:
# (9134, 24)

# %%
df.describe()
# Out:
#        Customer_Lifetime_Value        Income  Monthly_Premium_Auto  \
# count              9134.000000   9134.000000           9134.000000
# mean               8004.940475  37657.380009             93.219291
# std                6870.967608  30379.904734             34.407967
# min                1898.007675      0.000000             61.000000
# 25%                3994.251794      0.000000             68.000000
# 50%                5780.182197  33889.500000             83.000000
# 75%                8962.167041  62320.000000            109.000000
# max               83325.381190  99981.000000            298.000000
#
#        Months_Since_Last_Claim  Months_Since_Policy_Inception  \
# count              9134.000000                    9134.000000
# mean                 15.097000                      48.064594
# std                  10.073257                      27.905991
# min                   0.000000                       0.000000
# ...

# %%
print("Great no missing data above")
# Out:
# Great no missing data above

# %%
no_missing_cols = set(df.columns[df.isnull().mean() > 1])

# %%
fig=plt.figure(figsize=(10, 10), dpi= 80, facecolor='w', edgecolor='k')
plt.subplot(2, 2, 1)
state_ratio = df.State.value_counts()
(state_ratio/df.shape[0]).plot(kind="bar");
plt.title("State Ratio");

plt.subplot(2, 2, 2);
vehicle_model = df.Vehicle_Class.value_counts()
(state_ratio/df.shape[0]).plot(kind="pie");
plt.title("Vehicle Types");

# %%
fig=plt.figure(figsize=(10, 10), dpi= 80, facecolor='w', edgecolor='k')
plt.subplot(2, 2, 1)
policy_type = df.Policy.value_counts()
(state_ratio/df.shape[0]).plot(kind="barh");
plt.title("Policy Type Class");

plt.subplot(2, 2, 2);
vehicle_model = df.Coverage.value_counts()
(state_ratio/df.shape[0]).plot(kind="pie");
plt.title("Vehicle Caverage");

# %%
fig = plt.figure(figsize = (10,8))
ax = fig.gca()
df.hist(ax = ax);
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3267: UserWarning: To output multiple subplots, the figure containing the passed axes is being cleared
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
fig = plt.figure(figsize = (10,8))
ax = fig.gca()
sns.heatmap(df.corr(), annot=True, fmt="f");

# %%
fig = plt.figure(figsize = (10,8))
ax = fig.gca()
df["Customer_Lifetime_Value"].plot();
